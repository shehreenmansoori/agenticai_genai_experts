# %% [markdown]
# DATA STRUCTURES

# %% [markdown]
# #List

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20,30)
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 l.append(20,30)
#       2 l
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l1=[]
l1
# Out:
# []

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l==l1
# Out:
# True

# %%
print(id(l))
print(id(l1))
# Out:
# 2684961397824
# 2685015265152

# %%
l2=[]
l2
# Out:
# []

# %%
l2.append(10)
l2.append(10.45)
l2.append(True)
l2.append(4+11j)
l2.append('py')
l2.append([5,6,7]) #nested list
l2
# Out:
# [10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
l.clear()
l
# Out:
# []

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
l1.count(10)
# Out:
# 1

# %%
l1.extend(l2) #adds the 2nd list to the first one
l1
# Out:
# [10, 20, 30, 40, 50, 10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
l1.index(10)
# Out:
# 0

# %%
l1.index(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 l1.index(100)
#
# ValueError: 100 is not in list

# %%
l1.index('py')
# Out:
# 9

# %%
for i in l2:
    print(i)
# Out:
# 10
# 10.45
# True
# (4+11j)
# py
# [5, 6, 7]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
l1.insert(1,15)
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
sal=[1000,2000,3000]
sal
# Out:
# [1000, 2000, 3000]

# %%
sal[1]
# Out:
# 2000

# %%
l1.pop()
# Out:
# [5, 6, 7]

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 10, 10.45, True, (4+11j), 'py']

# %%
l1.pop(1)
# Out:
# 15

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 10, 10.45, True, (4+11j), 'py']

# %%
l1.pop(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 l1.pop(10)
#
# IndexError: pop index out of range

# %%
l1.remove(10.45)
l1
# Out:
# [10, 20, 30, 40, 50, 10, True, (4+11j), 'py']

# %% [markdown]
# 28 FEB

# %%
l=[1,2,3.40,'sys',1+3j]
l
# Out:
# [1, 2, 3.4, 'sys', (1+3j)]

# %%
l[3]
# Out:
# 'sys'

# %%
l[3][1]
# Out:
# 'y'

# %%
l[-1]
# Out:
# (1+3j)

# %%
l[0]=3
l[1]=2
l[2]=1
l
# Out:
# [3, 2, 1, 'sys', (1+3j)]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined
