# %% [markdown]
# DATA STRUCTURES

# %% [markdown]
# #List

# %%
l=[]
l

# %%
type(l)

# %%
len(l)
# Out:
# 1

# %%
l.append(10)
l
# Out:
# [10, 10]

# %%
l.append(20,30)
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 l.append(20,30)
#       2 l
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l

# %%
len(l)
# Out:
# 2

# %%
l1=[]
l1
# Out:
# []

# %%
l1=l.copy()
l1
# Out:
# [10, 10]

# %%
l==l1
# Out:
# True

# %%
print(id(l))
print(id(l1))
# Out:
# 2237225976064
# 2237279064192

# %%
l2=[]
l2
# Out:
# []

# %%
l2.append(10)
l2.append(10.45)
l2.append(True)
l2.append(4+11j)
l2.append('py')
l2.append([5,6,7]) #nested list
l2
# Out:
# [10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
l.clear()
l
# Out:
# []

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
l1.count(10)
# Out:
# 2

# %%
l1.extend(l2) #adds the 2nd list to the first one
l1
# Out:
# [10, 10, 10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
l1.index(10)
# Out:
# 0

# %%
l1.index(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 l1.index(100)
#
# ValueError: 100 is not in list

# %%
l1.index('py')
# Out:
# 6

# %%
for i in l2:
    print(i)
# Out:
# 10
# 10.45
# True
# (4+11j)
# py
# [5, 6, 7]

# %%
l1
# Out:
# [10, 10, 10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
l1.insert(1,15)
l1
# Out:
# [10, 15, 10, 10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
sal=[1000,2000,3000]
sal
# Out:
# [1000, 2000, 3000]

# %%
sal[1]
# Out:
# 2000

# %%
l1.pop()
# Out:
# [5, 6, 7]

# %%
l1
# Out:
# [10, 15, 10, 10, 10.45, True, (4+11j), 'py']

# %%
l1.pop(1)
# Out:
# 15

# %%
l1
# Out:
# [10, 10, 10, 10.45, True, (4+11j), 'py']

# %%
l1.pop(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 l1.pop(10)
#
# IndexError: pop index out of range

# %%
l1.remove(10.45)
l1
# Out:
# [10, 10, 10, True, (4+11j), 'py']

# %% [markdown]
# 28 FEB

# %%
l=[1,2,3.40,'sys',1+3j]
l
# Out:
# [1, 2, 3.4, 'sys', (1+3j)]

# %%
l[3]
# Out:
# 'sys'

# %%
l[3][1]
# Out:
# 'y'

# %%
l[-1]
# Out:
# (1+3j)

# %%
l[0]=3
l[1]=2
l[2]=1
l
# Out:
# [3, 2, 1, 'sys', (1+3j)]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
del l

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %% [markdown]
# #LIST SLICING

# %%
l1[:]
# Out:
# [10, 10, 10, True, (4+11j), 'py']

# %%
len(l1)
# Out:
# 6

# %%
l1[2:]
# Out:
# [10, True, (4+11j), 'py']

# %%
l1[:2] #n-1
# Out:
# [10, 10]

# %%
l1[::2]
# Out:
# [10, 10, (4+11j)]

# %%
l1[::3]
# Out:
# [10, True]

# %%
l1[1:6:5]
# Out:
# [10]

# %%
l1[::-1]
# Out:
# ['py', (4+11j), True, 10, 10, 10]

# %%
l1[::-2]
# Out:
# ['py', True, 10]

# %%
l2
# Out:
# [10, 10.45, True, (4+11j), 'py', [5, 6, 7]]

# %%
l3=['a','b','c']

# %%
l3[-4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 l3[-4]
#
# IndexError: list index out of range

# %%
l3[-4:]
# Out:
# ['a', 'b', 'c']

# %%
l3[0]='d' #LIST is MUTABLE
l3
# Out:
# ['d', 'b', 'c']

# %%
#nested index(index inside index)
print(l1[5][0])
print(l1[5][1])
# Out:
# p
# y

# %%
l1
# Out:
# [10, 10, 10, True, (4+11j), 'py']

# %%
l1[::-1] #Slicing doesnt change the list
# Out:
# ['py', (4+11j), True, 10, 10, 10]

# %%
l1
# Out:
# [10, 10, 10, True, (4+11j), 'py']

# %%
l1.reverse() #Reverse will store reverse list in memory
l1
# Out:
# ['py', (4+11j), True, 10, 10, 10]

# %%
l1
# Out:
# ['py', (4+11j), True, 10, 10, 10]

# %%
l3.sort()
l3
# Out:
# ['b', 'c', 'd']

# %%
l3.sort(reverse=True)
l3
# Out:
# ['d', 'c', 'b']

# %%
l1
# Out:
# ['py', (4+11j), True, 10, 10, 10]

# %%
l1.reverse()

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'complex' and 'bool'

# %%
for i in l1:
    print(i)
# Out:
# 10
# 10
# 10
# True
# (4+11j)
# py

# %%
for i in enumerate(l1):
    print(i)
# Out:
# (0, 10)
# (1, 10)
# (2, 10)
# (3, True)
# (4, (4+11j))
# (5, 'py')
