# %%
x=input()
x
# Out:
#  Hello
# 'Hello'

# %%
x=input()
y=input()

z=x+y
z
# Out:
#  4
#  5
# '45'

# %%
x=int(input())
y=int(input())
z=x+y
z
# Out:
#  4
#  5
# 9

# %%
x=int(input('Enter first no='))
y=int(input('Enter second no='))
z=x+y
z
# Out:
# Enter first no= 10
# Enter second no= 20
# 30

# %%
s=input('Enter a string=')
s
# Out:
# Enter a string= Hello
# 'Hello'

# %%
s=input('Enter a string=')[0]
s
# Out:
# Enter a string= Python
# 'P'

# %%
s=input('Enter a string=')[4:]
s
# Out:
# Enter a string= Hello all
# 'o all'

# %%
st=input('enter=')
st
# Out:
# enter= 50+20+47-90
# '50+20+47-90'

# %%
st=eval(input('enter='))
st
# Out:
# enter= 50+20+47-90
# 27
