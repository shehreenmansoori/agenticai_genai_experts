# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image #python image library

# %%
ele = Image.open(r"C:\Users\Shiroz\OneDrive\Desktop\elephant.jpeg")

# %%
ele
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x214>

# %%
type(ele)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np

# %%
ele_arr= np.asarray(ele)
ele_arr
# Out:
# array([[[182, 111, 107],
#         [175, 104, 100],
#         [172, 101,  97],
#         ...,
#         [160, 114, 116],
#         [163, 117, 119],
#         [170, 124, 126]],
#
#        [[182, 111, 107],
#         [175, 104, 100],
#         [172, 101,  97],
#         ...,
#         [160, 114, 116],
#         [163, 117, 119],
#         [170, 124, 126]],
#
#        [[183, 112, 108],
#         [176, 105, 101],
#         [172, 101,  97],
#         ...,
#         [159, 115, 116],
#         [162, 118, 119],
#         [169, 125, 126]],
#
#        ...,
#
#        [[ 87,  59,  45],
#         [ 81,  53,  39],
#         [ 73,  45,  31],
#         ...,
#         [107,  72,  52],
#         [109,  74,  54],
#         [114,  79,  59]],
#
#        [[ 77,  49,  35],
#         [ 73,  45,  31],
#         [ 69,  41,  27],
#         ...,
#         [105,  70,  50],
#         [104,  69,  49],
#         [108,  73,  53]],
#
#        [[ 69,  41,  27],
#         [ 69,  41,  27],
#         [ 69,  41,  27],
# ...

# %%
plt.imshow(ele_arr)
