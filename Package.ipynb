# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(144))
# Out:
# 12

# %%
math.floor(4.56)
# Out:
# 4

# %%
math.ceil(4.56)
# Out:
# 5

# %%
math.pow(9,2)
# Out:
# 81.0

# %%
import math as m

# %%
m.pow(9,2)
# Out:
# 81.0

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
from math import floor,ceil,pow,sqrt
print(pow(3,4))
print(sqrt(144))
print(ceil(6.98))
print(floor(6.98))
# Out:
# 81.0
# 12.0
# 7
# 6

# %%
from math import *
print(pow(3,4))
print(sqrt(144))
print(ceil(6.98))
print(floor(6.98))
# Out:
# 81.0
# 12.0
# 7
# 6
