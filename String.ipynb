# %% [markdown]
# String

# %%
str='Hello world'
print(str)
# Out:
# Hello world

# %%
print(str[0])
# Out:
# H

# %%
str1=('wohoo')
str1=str1*5
str1
# Out:
# 'wohoowohoowohoowohoowohoo'

# %%
len(str)
# Out:
# 11

# %%
str
# Out:
# 'Hello world'

# %%
str[0]
# Out:
# 'H'

# %%
str[0:5]
# Out:
# 'Hello'

# %%
str[-6]
# Out:
# ' '

# %%
str[-4:]
# Out:
# 'orld'

# %%
str2=str+str1
print(str2)
# Out:
# Hello worldwohoowohoowohoowohoowohoo
