# %% [markdown]
# NUMBER SYSTEM

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(0)
# Out:
# '0x0'

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(11)
# Out:
# '0xb'

# %%
hex(12)
# Out:
# '0xc'

# %%
hex(13)
# Out:
# '0xd'

# %%
hex(14)
# Out:
# '0xe'

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %% [markdown]
# BITWISE OPERATOR

# %% [markdown]
# #Complement (~)

# %%
~10
# Out:
# -11

# %%
~24
# Out:
# -25

# %% [markdown]
# #And (&)

# %%
12 & 13
# Out:
# 12

# %% [markdown]
# #or (|)

# %%
12 | 13
# Out:
# 13

# %% [markdown]
# #xor (^)

# %%
12 ^ 13
# Out:
# 1

# %% [markdown]
# #left shift

# %%
12<<1
# Out:
# 24

# %% [markdown]
# #right shift

# %%
12>>3
# Out:
# 1

# %%
12>>2
# Out:
# 3

# %%
15>>2
# Out:
# 3
