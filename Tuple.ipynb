# %% [markdown]
# TUPLE

# %%
t1=(1,2,3,4,5,5)
t1
# Out:
# (1, 2, 3, 4, 5, 5)

# %%
t2=(1,2.3,'python',3+5j)
t2
# Out:
# (1, 2.3, 'python', (3+5j))

# %%
print(type(t2))
# Out:
# <class 'tuple'>

# %%
t1.count(5)
# Out:
# 2

# %%
t2.count(1)
# Out:
# 1

# %%
t1.index(3)
# Out:
# 2

# %%
t1[:4]
# Out:
# (1, 2, 3, 4)

# %%
t1[5]=6 #Immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t1[5]=6 #Immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1*4
# Out:
# (1, 2, 3, 4, 5, 5, 1, 2, 3, 4, 5, 5, 1, 2, 3, 4, 5, 5, 1, 2, 3, 4, 5, 5)

# %% [markdown]
# #TUPLE INDEXING

# %%
t1[0]
# Out:
# 1

# %%
t2=('hello','welcome','python')
t2
# Out:
# ('hello', 'welcome', 'python')

# %%
t2[1]
# Out:
# 'welcome'

# %%
t2[2][1] #nested indexing
# Out:
# 'y'

# %%
t2[-1]
# Out:
# 'python'

# %%
t2[-2]
# Out:
# 'welcome'

# %%
del t1

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %% [markdown]
# #TUPLE MEMBERSHIP

# %%
t2
# Out:
# ('hello', 'welcome', 'python')

# %%
'hello' in t2
# Out:
# True

# %%
'hi' in t2
# Out:
# False

# %% [markdown]
# #SORTING

# %%
t3=(45,59,30,82,21)
t3
# Out:
# (45, 59, 30, 82, 21)

# %%
sorted(t3)
# Out:
# [21, 30, 45, 59, 82]

# %%
sorted(t3,reverse=True)
# Out:
# [82, 59, 45, 30, 21]
