# %% [markdown]
# STRING

# %%
s1="welcome people"
s1
# Out:
# 'welcome people'

# %%
s1[:]
# Out:
# 'welcome people'

# %%
s1[::-1]
# Out:
# 'elpoep emoclew'

# %%
s1[2:10]
# Out:
# 'lcome pe'

# %%
s1[::-2]
# Out:
# 'epe mce'

# %%
s1[1:9:2]
# Out:
# 'ecm '
